# %%
print("Bonjour")
# Out:
# Bonjour

# %% [markdown]
# # tokenisation

# %%
import tiktoken

# %%
tokenizer = tiktoken.encoding_for_model("gpt-4o")

# %%
print(tokenizer.name)
# Out:
# o200k_base

# %%
tokenizer=tiktoken.get_encoding("o200k_base")

# %%
prompt = "Vous êtes un expert en economie. Qu'est-ce que l'inflation ?"

# %%
tokens=tokenizer.encode(prompt)

# %%
print(tokens)
# Out:
# [29038, 34077, 537, 8333, 469, 119408, 13, 3106, 6616, 35404, 661, 305, 17942, 1836, 387, 1423]

# %%
print(len(tokens))
# Out:
# 16

# %%
for token in tokens:
    t=tokenizer.decode_single_token_bytes(token).decode("utf-8")
    print(t,end='|')
# Out:
# Vous| êtes| un| expert| en| economie|.| Qu|'est|-ce| que| l|'in|fl|ation| ?|

# %% [markdown]
# # Utilisation des llm

# %%
from langchain_openai import ChatOpenAI
from dotenv.ipython import load_dotenv

# %%
load_dotenv(override=True)
# Out:
# True

# %%
llm=ChatOpenAI(model="gpt-4o", temperature=0)
# Out:
# KeyboardInterrupt

# %%
resp=llm.invoke(input=[{"role":"system","content":"Vous êtes un expert en economie"},{"role":"user","content":"C'est quoi l'inflation ?"}])

# %%
print(resp.content)

# %%
from IPython.display import Markdown

# %%
print(display(Markdown(resp.content)))

# %% [markdown]
# # ollama llm

# %%
from langchain_ollama import ChatOllama

# %%
#llm2=ChatOllama(model="qwen3.5:cloud", temperature=0)
llm2=ChatOllama(model="qwen3-coder:480b-cloud", temperature=0)

# %%
resp2=llm2.invoke(input=[{"role":"system","content":"Vous êtes un expert en economie"},{"role":"user","content":"C'est quoi l'inflation ?"}])

# %%
print(display(Markdown(resp2.content)))
# Out:
# L'inflation est l'augmentation générale et soutenue des prix des biens et services dans une économie sur une période donnée.
#
# ## Caractéristiques principales :
#
# **📈 Effet sur le pouvoir d'achat**
# - Chaque unité de monnaie permet d'acheter moins de biens et services
# - Le coût de la vie augmente
#
# **📊 Mesure de l'inflation**
# - Indice des Prix à la Consommation (IPC)
# - Taux d'inflation annuel : exemple 2% par an
#
# ## Causes principales :
#
# - **Demande excédentaire** : trop de demande pour trop peu d'offre
# - **Coûts de production** : hausse des prix des matières premières, salaires
# - **Politique monétaire** : augmentation de la masse monétaire
# - **Chocs externes** : pénuries, tensions géopolitiques
#
# ## Conséquences :
#
# **Négatives :**
# - Perte de pouvoir d'achat
# - Incertitude économique
# - Redistribution arbitraire de richesse
#
# **Positives (modérée) :**
# - Encourage la consommation et l'investissement
# - Réduit le fardeau de la dette
#
# ...
